# %% [markdown]
# # 1.3 Searching text
#
# ## Concordance
#
# Search for a word and see its context.

# %%
import nltk
from nltk.book import *
import re
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams["font.size"] = 16
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# find "monstrous" in moby dick
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
# find "affection" in sense and sensibility
text2.concordance("affection")
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %%
# find "lived" in the book of genesis
text3.concordance("lived")
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
# find "terror" in inaugural address corpus
text4.concordance("terror")
# Out:
# Displaying 8 of 8 matches:
# menaces , by fraud or violence , by terror , intrigue , or venality , the Gove
# ameless , unreasoning , unjustified terror which paralyzes needed efforts to c
# ublic seemed frozen by a fatalistic terror , we proved that this is not true .
#  to alter that uncertain balance of terror that stays the hand of mankind ' s
# eans freeing all Americans from the terror of runaway living costs . All must
# still . They fuel the fanaticism of terror . And they torment the lives of mil
# d maintain a strong defense against terror and destruction . Our children will
# k to advance their aims by inducing terror and slaughtering innocents , we say

# %% [markdown]
# ## Similar words and common contexts
#
# Similarity here is based on conext, i.e., what comes before and after the word.

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
# my turn
text3.similar("great")
# Out:
# not found there be good second one se tree third fourth man put gold
# bdellium stone euphrates thereof taken woman

# %%
text3.common_contexts(["great", "found"])
# Out:
# was_in is_and

# %% [markdown]
# ## Dispersion plot
#
# See the occurence of words in the whole text.

# %%
text3.dispersion_plot(["Adam", "Eve", "Abraham", "Isaac", "Jacob"])
# Out:
# /home/waseem/.local/lib/python3.8/site-packages/nltk/draw/__init__.py:15: UserWarning: nltk.draw package not loaded (please install Tkinter library).
#   warnings.warn("nltk.draw package not loaded " "(please install Tkinter library).")

# %%
text3.generate()
# Out:
# Building ngram index...
# laid by her , and said unto Cain , Where art thou , and said , Go to ,
# I will not do it for ten ' s sons ; we dreamed each man according to
# their generatio the firstborn said unto Laban , Because I said , Nay ,
# but Sarah shall her name be . , duke Elah , duke Shobal , and Akan .
# and looked upon my affliction . Bashemath Ishmael ' s blood , but Isra
# for as a prince hast thou found of all the cattle in the valley , and
# the wo The
# "laid by her , and said unto Cain , Where art thou , and said , Go to ,\nI will not do it for ten ' s sons ; we dreamed each man according to\ntheir generatio the firstborn said unto Laban , Because I said , Nay ,\nbut Sarah shall her name be . , duke Elah , duke Shobal , and Akan .\nand looked upon my affliction . Bashemath Ishmael ' s blood , but Isra\nfor as a prince hast thou found of all the cattle in the valley , and\nthe wo The"

# %% [markdown]
# # 1.4 Counting
#
# ## Tokens (all and distinct)

# %%
# length (number of word and punctuation symbols)
len(text3)
# Out:
# 44764

# %%
# number of unique items
len(set(text3))
# Out:
# 2789

# %% [markdown]
# ### _side experiment: `set()`_

# %%
a_set = set(['a', 'b', 'a', 'c', 'b', 'd', 'e'])
print(a_set)
type(a_set)
# Out:
# {'b', 'a', 'c', 'e', 'd'}
# set

# %% [markdown]
# ### _side experiment: count words without punctuation_

# %%
rgx = re.compile("[A-Za-z]")
len(list(filter(rgx.match, set(text3))))
# Out:
# 2776

# %% [markdown]
# ## Lexical richness

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

def pcnt(count, total):
    return 100 * count / total

# %%
print(
    "Lexical Diversity of text 3",
    lexical_diversity(text3),
    "Lexical Diversity of text 5",
    lexical_diversity(text5),
    "Percentage of \"lol\" in text 5",
    pcnt(text5.count("lol"), len(text5)),
    
    sep = "\n"
)
# Out:
# Lexical Diversity of text 3
# 0.06230453042623537
# Lexical Diversity of text 5
# 0.13477005109975562
# Percentage of "lol" in text 5
# 1.5640968673628082

# %% [markdown]
# * * *
#
# # 2.1 Lists

# %%
sntc1 = "Sharp edges have consequences. Now, every scar is a story I can tell."
sntc2 = "No lyrics because this is the awesome Westworld soundtrack!"

lexical_diversity((sntc1 + " " + sntc2).split())
# Out:
# 0.9545454545454546

# %% [markdown]
# * * *
#
# # 3.1 Frequency distributions

# %%
# warm up exercise
saying = "After all is said than done more is said than done".split()
tokens = sorted(set(saying))
tokens[-2:]
# Out:
# ['said', 'than']

# %%
fdist1 = FreqDist(text1)
fdist1.most_common(15)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124)]

# %%
fdist1.plot(50, cumulative = True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %% [markdown]
# ### _side experiment:  same plot without punctuation_

# %%
FreqDist(list(filter(rgx.match, text1))) \
    .plot(50, cumulative = True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %% [markdown]
# ## Hapaxes
#
# Words that occur only once in the document text.

# %%
fdist1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %% [markdown]
# # 3.2 Fine-grained selection of words

# %%
[w for w in set(text1) if len(w) > 15]
# Out:
# ['physiognomically',
#  'uncomfortableness',
#  'circumnavigations',
#  'indispensableness',
#  'subterraneousness',
#  'uncompromisedness',
#  'CIRCUMNAVIGATION',
#  'irresistibleness',
#  'comprehensiveness',
#  'characteristically',
#  'supernaturalness',
#  'indiscriminately',
#  'superstitiousness',
#  'circumnavigating',
#  'circumnavigation',
#  'uninterpenetratingly',
#  'responsibilities',
#  'simultaneousness',
#  'apprehensiveness',
#  'Physiognomically',
#  'cannibalistically',
#  'hermaphroditical',
#  'undiscriminating',
#  'preternaturalness']

# %% [markdown]
# ### _side experiment: filter()_

# %%
list(filter(lambda x: len(x) > 15, set(text1)))
# Out:
# ['physiognomically',
#  'uncomfortableness',
#  'circumnavigations',
#  'indispensableness',
#  'subterraneousness',
#  'uncompromisedness',
#  'CIRCUMNAVIGATION',
#  'irresistibleness',
#  'comprehensiveness',
#  'characteristically',
#  'supernaturalness',
#  'indiscriminately',
#  'superstitiousness',
#  'circumnavigating',
#  'circumnavigation',
#  'uninterpenetratingly',
#  'responsibilities',
#  'simultaneousness',
#  'apprehensiveness',
#  'Physiognomically',
#  'cannibalistically',
#  'hermaphroditical',
#  'undiscriminating',
#  'preternaturalness']

# %% [markdown]
# ## Tokens that are both long and common
#
# More than 7 character long and occurring more than 7 times.

# %%
fdist5 = FreqDist(text5)
sorted([w for w in set(text5) if (len(w) > 7 and fdist5[w] > 7)])
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %% [markdown]
# # 3.3 Collocations and bigrams

# %%
list(bigrams("more is said than done".split()))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; God
# bless; Chief Justice; Old World; Almighty God; Fellow citizens; Chief
# Magistrate; every citizen; one another; fellow Americans; Indian
# tribes; public debt; foreign nations

# %% [markdown]
# # 3.4 Counting other things
#
# ## Frequency distribution of lengths

# %%
word_len1 = [len(w) for w in text1]
fdist = FreqDist(word_len1)
fdist.plot(25)
print(fdist[20])
# Out:
# 1

# %%
print(
    fdist1.freq("monstrous"),
    fdist1["monstrous"]/fdist1.N(),
    
    sep = "\n"
)
# Out:
# 3.834076505162584e-05
# 3.834076505162584e-05

# %% [markdown]
# # Exercises
#
# ## 1. ☼ Try using the Python interpreter as a calculator, and typing expressions like 12 / (4 + 1).

# %%
print(
    12 / (4 + 1),
    81 // 10,      # integer division
    81 % 10,       # modulo (remainder)
    5 ** 2,        # exponent
    
    sep = "\n"
)
# Out:
# 2.4
# 8
# 1
# 25

# %% [markdown]
# ## 2. ☼ Given an alphabet of 26 letters, there are 26 to the power 10, or 26 ** 10, ten-letter strings we can form. That works out to 141167095653376. How many hundred-letter strings are possible?

# %%
# num_letters ** combination_length
26 ** 10
26 ** 100   # :D
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# ## 3. ☼ The Python multiplication operation can be applied to lists. What happens when you type ['Monty', 'Python'] * 20, or 3 * sent1?

# %%
["Monty", "Python"] * 3
# Out:
# ['Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python']

# %% [markdown]
# ## 4. ☼ How many words are there in text2? How many distinct words are there?

# %%
print(
    len(text2),
    len(set([w.lower() for w in text2]))
)
# Out:
# 141576 6403

# %% [markdown]
# ## 5. ☼ Compare the lexical diversity scores for humor and romance fiction in 1.1. Which genre is more lexically diverse?

# %%
humor_div = 5017 / 21695
romanc_div = 8452 / 70022

humor_div > romanc_div
# Out:
# True

# %% [markdown]
# ## 6. ☼ Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
text2.dispersion_plot(["Edward", "Elinor", "", "Willoughby", "Marianne"])

# %% [markdown]
# ## 7. ☼ Find the collocations in text5.

# %%
text5.collocation_list()
# Out:
# [('wanna', 'chat'),
#  ('PART', 'JOIN'),
#  ('MODE', '#14-19teens'),
#  ('JOIN', 'PART'),
#  ('PART', 'PART'),
#  ('cute.-ass', 'MP3'),
#  ('MP3', 'player'),
#  ('JOIN', 'JOIN'),
#  ('times', '.. .'),
#  ('ACTION', 'watches'),
#  ('guys', 'wanna'),
#  ('song', 'lasts'),
#  ('last', 'night'),
#  ('ACTION', 'sits'),
#  ('-...)...-', 'S.M.R.'),
#  ('Lime', 'Player'),
#  ('Player', '12%'),
#  ('dont', 'know'),
#  ('lez', 'gurls'),
#  ('long', 'time')]

# %% [markdown]
# ## 8. ☼ Consider the following Python expression: `len(set(text4))`. State the purpose of this expression. Describe the two steps involved in performing this computation.
#
# - `text4` is an object containing the Inaugural Address Corpus
# - Calling `set()` on `text4` returns the unique words.
# - Calling `len()` on `set(text4)` returns the number of unique words.
#
# Note that this process is case-sensitive. So, if the same word occurrs in two different cases, it will be counted twice.

# %% [markdown]
# ## 9. Review 2 on lists and strings.
#
# ### a. Define a string and assign it to a variable, e.g., `my_string = 'My String'`. Print the contents of this variable in two ways, first by simply typing the variable name and pressing enter, then by using the print statement.
#
# ### b. Try adding the string to itself using `my_string + my_string`, or multiplying it by a number, e.g., `my_string * 3`. Notice that the strings are joined together without any spaces. How could you fix this?

# %%
my_string = "It wears her down."
print(my_string)
my_string
# Out:
# It wears her down.
# 'It wears her down.'

# %%
print(
    "addition",
    my_string + my_string,
    "\nmultiplication",
    my_string * 3,
    "\nadding spaces",
    my_string + " " + my_string,
    
    sep = "\n"
)
# Out:
# addition
# It wears her down.It wears her down.
#
# multiplication
# It wears her down.It wears her down.It wears her down.
#
# adding spaces
# It wears her down. It wears her down.

# %% [markdown]
# ## 10. ☼ Define a variable `my_sent` to be a list of words, using the syntax `my_sent = ["My", "sent"]`
#
# - Use `' '.join(my_sent)` to convert this into a string.
# - Use `split()` to split the string back into the list form you had to start with.

# %%
my_sent = ["My", "sent"]
print(
    ' '.join(my_sent),
    ' '.join(my_sent).split(),
    
    sep = "\n"
)
# Out:
# My sent
# ['My', 'sent']

# %% [markdown]
# ## 11. ☼ Define several variables containing lists of words, e.g., phrase1, phrase2, and so on. Join them together in various combinations (using the plus operator) to form whole sentences. What is the relationship between len(phrase1 + phrase2) and len(phrase1) + len(phrase2)?

# %%
phrase1 = "I woke up"
phrase2 = "I remember"
phrase3 = "Halfway right"
print(
    phrase1 + phrase2 + phrase3,
    (len(phrase1), len(phrase2), len(phrase3)),
    len(phrase1 + phrase2 + phrase3),
    len(phrase1) + len(phrase2) + len(phrase3),
    
    sep = "\n"
)
# Out:
# I woke upI rememberHalfway right
# (9, 10, 13)
# 32
# 32

# %% [markdown]
# ## 12. ☼ Consider the following two expressions, which have the same value. Which one will typically be more relevant in NLP? Why?
#
# a. `"Monty Python"[6:12]`
#
# b. `["Monty", "Python"][1]`
#
# The second expression is the more relevant one in NLP, because NLP analyzes text at the token level.

# %% [markdown]
# ## 13. ☼ We have seen how to represent a sentence as a list of words, where each word is a sequence of characters. What does sent1[2][2] do? Why? Experiment with other index values.
#
# - The first `[2]` takes the third _element_ of the word list, which returns a string (of a word).
# - The second `[2]` takes the third _character_ of the third word (the result of `sent1[2]`).

# %%
print(
    sent1,
    sent1[2],
    sent1[2][2],

    sep = "\n"
)
# Out:
# ['Call', 'me', 'Ishmael', '.']
# Ishmael
# h

# %% [markdown]
# ## 14. ☼ The first sentence of text3 is provided to you in the variable `sent3`. The index of "the" in `sent3` is 1, because `sent3[1]` gives us "the". What are the indexes of the two other occurrences of this word in sent3?

# %%
i_the = [i for i in range(len(sent3)) if sent3[i] == "the"]
print(i_the)

for i in i_the:
    print(sent3[i])
# Out:
# [1, 5, 8]
# the
# the
# the

# %% [markdown]
# ## 15. ☼ Find all words in the Chat Corpus (text5) starting with the letter b. Show them in alphabetical order.

# %%
set(sorted([w for w in text5 if w.startswith("b")]))
# Out:
# {'b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
#  'backup',
#  'bacl',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bahahahaa',
#  'bak',
#  'baked',
#  'balad',
#  'balance',
#  'balck',
#  'ball',
#  'ballin',
#  'balls',
#  'ban',
#  'band',
#  'bandito',
#  'bandsaw',
#  'banjoes',
#  'banned',
#  'baord',
#  'bar',
#  'barbie',
#  'bare',
#  'barely',
#  'bares',
#  'barfights',
#  'barks',
#  'barn',
#  'barrel',
#  'base',
#  'bases',
#  'basically',
#  'basket',
#  'battery',
#  'bay',
#  'bbbbbyyyyyyyeeeeeeeee',
#  'bbiam',
#  'bbl',
#  'bbs',
#  'bc',
#  'be',
#  'beach',
#  'beachhhh',
#  'beam',
#  'beams',
#  'beanbag',
#  'beans',
#  'bear',
#  'bears',
#  'beat',
#  'beaten',
#  'beatles',
#  'beats',
#  'beattles',
#  'beautiful',
# ...

# %% [markdown]
# ## 16. ☼ Type the expression `list(range(10))` at the interpreter prompt.

# %%
print(
    list(range(5)),
    list(range(8,10)),
    list(range(10, 20, 2)),
    list(range(20, 10, -2))
)
# Out:
# [0, 1, 2, 3, 4] [8, 9] [10, 12, 14, 16, 18] [20, 18, 16, 14, 12]

# %% [markdown]
# ## 17. ◑ Use `text9.index()` to find the index of the word sunset. You'll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
i_sunset = text9.index("sunset")
i_dot = [i for i in range(len(text9)) if text9[i] == "."]
i_before_sunset = [i for i in i_dot if i < i_sunset]
i_after_sunset  = [i for i in i_dot if i > i_sunset]

' '.join(
    text9[ (i_before_sunset[-1]+1) : (i_after_sunset[0]) ]
)
# Out:
# 'CHAPTER I THE TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset'

# %% [markdown]
# ## 18. ◑ Using list addition, and the set and sorted operations, compute the vocabulary of the sentences sent1 ... sent8.
#
# Not sure what the question means, but I will assume I need to combine the 8 sentences and make a whole vocabulary of uniqe words from them.

# %%
all_sents = sent1 + sent2 + sent3 + sent4 + sent5 + sent6 + sent7 + sent8
sorted(set(
    ' '.join(all_sents) \
        .lower() \
        .split()
))
# Out:
# ['!',
#  ',',
#  '-',
#  '.',
#  '1',
#  '25',
#  '29',
#  '61',
#  ':',
#  '[',
#  ']',
#  'a',
#  'and',
#  'arthur',
#  'as',
#  'attrac',
#  'been',
#  'beginning',
#  'board',
#  'call',
#  'citizens',
#  'clop',
#  'created',
#  'dashwood',
#  'director',
#  'discreet',
#  'earth',
#  'encounters',
#  'family',
#  'fellow',
#  'for',
#  'god',
#  'had',
#  'have',
#  'heaven',
#  'house',
#  'i',
#  'in',
#  'ishmael',
#  'join',
#  'king',
#  'lady',
#  'lol',
#  'long',
#  'male',
#  'me',
#  'nonexecutive',
#  'nov.',
#  'of',
#  'old',
#  'older',
#  'people',
#  'pierre',
#  'pming',
#  'problem',
#  'representatives',
#  'scene',
#  'seeks',
#  'senate',
#  'settled',
#  'sexy',
#  'single',
#  'sussex',
#  'the',
#  'there',
#  'to',
#  'vinken',
#  'whoa',
#  'will',
#  'wind',
#  'with',
#  'years']

# %% [markdown]
# ## 19. ◑ What is the difference between the following two lines? Which one will give a larger value? Will this be the case for other texts?
#
# ```
# >>> sorted(set(w.lower() for w in text1))
# >>> sorted(w.lower() for w in set(text1))
# ```
#
# - The second one will give a larger value, because `lower()` is called on the list resulting from `set(text1)`, which might contain words counted more than once due to different cases.
#
# - In contrast, the first one converts the text to lowercase _before_ calling `set()`, which would make the words of the same case before extracting the distinct ones.

# %%
print(
    len(sorted(set(w.lower() for w in text1))),
    len(sorted(w.lower() for w in set(text1)))
)
# Out:
# 17231 19317

# %% [markdown]
# ## 20. ◑ What is the difference between the following two tests: `w.isupper()` and `not w.islower()`?

# %% [markdown]
# Both should produce the same results except when given mixed case strings or strings with only puncuation symbols and no letters: `isupper()` will always be `False`, and `islower()` will also be `False` whose negation will always be `True`.

# %%
print(
    "HELLO".isupper(),
    "hello".isupper(),
    "heLlO".isupper(),
    "HELLO...".isupper(),
    "hello...".isupper(),
    "^#$@$".isupper()
)
print(
    not "HELLO".islower(),
    not "hello".islower(),
    not "heLlO".islower(),
    not "HELLO...".islower(),
    not "hello...".islower(),
    not "^#$@$".isupper()
)
# Out:
# True False False True False False
# True False True True False True

# %% [markdown]
# ## 21. ◑ Write the slice expression that extracts the last two words of text2.

# %%
text2[-2:]
# Out:
# ['THE', 'END']

# %% [markdown]
# ## 22. ◑ Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
text5_four_letters = [w.lower() for w in text5 if len(w) == 4]
fdist5_four_letters = FreqDist(text5_four_letters)

print(fdist5_four_letters.most_common(10))
fdist5_four_letters.plot(10)
# Out:
# [('part', 1022), ('join', 1021), ('that', 284), ('what', 201), ('here', 185), ('have', 171), ('....', 170), ('like', 160), ('with', 154), ('chat', 146)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## 23. ◑ Use a combination of for and if statements to loop over the words of the movie script for Monty Python and the Holy Grail (text6) and print all the uppercase words, one per line.

# %%
for w in text6:
    if w.isupper():
        print(w)
# Out:
# SCENE
# KING
# ARTHUR
# SOLDIER
# ARTHUR
# I
# SOLDIER
# ARTHUR
# I
# I
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# I
# ARTHUR
# I
# SOLDIER
# SOLDIER
# SOLDIER
# I
# ARTHUR
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SCENE
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# SCENE
# ARTHUR
# DENNIS
# ...

# %% [markdown]
# ## 24. ◑ Write expressions for finding all words in text6 that meet the conditions listed below. The result should be in the form of a list of words: ['word1', 'word2', ...].
#
# - Ending in ise
# - Containing the letter z
# - Containing the sequence of letters pt
# - Having all lowercase letters except for an initial capital (i.e., titlecase)

# %%
print(
    [w for w in text6 if w.endswith("ise")],
    [w for w in text6 if "z" in w],
    [w for w in text6 if "pt" in w],
    [w for w in text6 if w.istitle()],
    sep = "\n"
)
# Out:
# ['wise', 'wise', 'apologise', 'surprise', 'surprise', 'surprise', 'noise', 'surprise']
# ['zone', 'amazes', 'Fetchez', 'Fetchez', 'zoop', 'zoo', 'zhiv', 'frozen', 'zoosh']
# ['empty', 'aptly', 'Thpppppt', 'Thppt', 'Thppt', 'empty', 'Thppppt', 'temptress', 'temptation', 'ptoo', 'Chapter', 'excepting', 'Thpppt']
# ...

# %% [markdown]
# ## 25. ◑ Define sent to be the list of words ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']. Now write code to perform the following tasks:
#
#
# - Print all words beginning with sh
# - Print all words longer than four characters

# %%
sent = ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']

print(
    [w for w in sent if w.startswith("sh")],
    [w for w in sent if len(w) > 4]
)
# Out:
# ['she', 'shells', 'shore'] ['sells', 'shells', 'shore']

# %% [markdown]
# ### _side experiment: filter()_

# %%
print(
    list(filter(lambda w: w.startswith("sh"), sent)),
    list(filter(lambda w: len(w) > 4, sent))
)
# Out:
# ['she', 'shells', 'shore'] ['sells', 'shells', 'shore']

# %% [markdown]
# ## 26. ◑ What does the following Python code do? `sum(len(w) for w in text1)` Can you use it to work out the average word length of a text?
#
# This counts the number of characters in the text, i.e., sums all the word lenghts.

# %%
def avg(lst):
    return sum(lst) / len(lst)

# already defined earlier
# word_len1 = [len(w) for w in text1]
avg(word_len1)
# Out:
# 3.830411128023649

# %% [markdown]
# ## 27. ◑ Define a function called `vocab_size(text)` that has a single parameter for the text, and which returns the vocabulary size of the text.
#
# - Note: he words will be converted to lowercase before vocabulary extraction to prevent double counting.

# %%
def vocab_size(text):
    return len(set([w.lower() for w in text]))
    
vocab_size(text1)
# Out:
# 17231

# %% [markdown]
# ##  28. ◑ Define a function percent(word, text) that calculates how often a given word occurs in a text, and expresses the result as a percentage.

# %%
def percent(word, text):
    
    n_word = len([w for w in text if w == word])
    n_text = len(text)
    ratio  = n_word / n_text
    
    return str(round(100 * ratio, 4)) + "%"

percent("the", text1)
# Out:
# '5.2607%'

# %% [markdown]
# ## 29. ◑ We have been using sets to store vocabularies. Try the following Python expression: set(sent3) < set(text1). Experiment with this using different arguments to set(). What does it do? Can you think of a practical application for this?
#
# (I suppose) it checks if the first element of the set is less than (i.e., alphabetically before) the first element of the second set; if they are equal, the process is repeated on the second element of each list, and so on.

# %%
set(sent1) < set(text4[-5:])
# Out:
# False
